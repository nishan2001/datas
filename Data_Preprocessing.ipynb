# %% [markdown]
# <a href="https://colab.research.google.com/github/nishan2001/datas/blob/main/Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings('ignore')

# Handling the data
import re
import string
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from collections import Counter

# Data visulization
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.subplots import make_subplots
# NLP tools
import nltk
import spacy
nlp = spacy.load("en_core_web_sm")
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer

import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# RNN
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,GRU,Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping,ReduceLROnPlateau
from tensorflow.keras.layers import Dense,Dropout,Embedding,BatchNormalization,SpatialDropout1D

# Vader
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Models evaluation
from sklearn.metrics import confusion_matrix

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
data = pd.read_csv('Restaurant_Reviews.csv')
data.head()
# Out:
#                                               Review  Liked
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1

# %%
data.tail()
# Out:
#                                                 Review  Liked
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0

# %%
data.shape
# Out:
# (1000, 2)

# %%
data['Liked'] = data['Liked'].map({0:'Negative',1:'Positive'})

# %%
data.describe().T
# Out:
#        count unique       top freq
# Review  1000    993    #NAME?    4
# Liked   1000      2  Positive  500

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Review  1000 non-null   object
#  1   Liked   1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %%
data.columns
# Out:
# Index(['Review', 'Liked'], dtype='object')

# %%
mapping = {"ain't": "is not", "aren't": "are not","can't": "cannot",
           "'cause": "because", "could've": "could have", "couldn't": "could not",
           "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not",
           "hasn't": "has not", "haven't": "have not", "he'd": "he would","he'll": "he will",
           "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will",
           "how's": "how is",  "I'd": "I would", "I'd've": "I would have", "I'll": "I will",
           "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",
           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have",
           "i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",
            "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have",
           "it's": "it is", "let's": "let us", "ma'am": "madam", "mayn't": "may not",
           "might've": "might have","mightn't": "might not","mightn't've": "might not have",
           "must've": "must have", "mustn't": "must not", "mustn't've": "must not have",
           "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",
           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not",
           "sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would",
           "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have",
           "she's": "she is", "should've": "should have", "shouldn't": "should not",
           "shouldn't've": "should not have", "so've": "so have","so's": "so as", "this's": "this is",
           "that'd": "that would", "that'd've": "that would have", "that's": "that is",
           "there'd": "there would", "there'd've": "there would have", "there's": "there is",
           "here's": "here is","they'd": "they would", "they'd've": "they would have",
           "they'll": "they will", "they'll've": "they will have", "they're": "they are",
           "they've": "they have", "to've": "to have", "wasn't": "was not", "we'd": "we would",
           "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have",
           "we're": "we are", "we've": "we have", "weren't": "were not",
           "what'll": "what will", "what'll've": "what will have","what're": "what are",
           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have",
           "where'd": "where did", "where's": "where is", "where've": "where have", "who'll": "who will",
           "who'll've": "who will have", "who's": "who is", "who've": "who have", "why's": "why is",
           "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",
           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have",
           "y'all": "you all", "y'all'd": "you all would","y'all'd've": "you all would have",
           "y'all're": "you all are","y'all've": "you all have","you'd": "you would",
           "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",
           "you're": "you are", "you've": "you have" ,"'ll":"will","'d":"would"}

# %%
stop_words = set(stopwords.words('english'))
stop_words.remove('not')
'not' in stop_words
# Out:
# False

# %%
print('Original :',data.Review.iloc[1])
print('processed with not removing negation :',' '.join([word for word in data.Review.iloc[1].split() if word not in stop_words]))
# Out:
# Original : Crust is not good.
# processed with not removing negation : Crust not good.

# %%
def text_preprocessing(text,lemmatize=False):
    '''input    : the text you want to process.
       output   : the processed text '''

    # Remove html tags
    text = BeautifulSoup(text, 'html.parser')
    text = text.get_text()
    # Lowercasing
    text = text.lower()
    # Removal of special characters, URLs, and mentions
    text = re.sub(r'http\S+|www\S+|https\S+|@[^\s]+', '', text)
    # remove more than one space with one space
    text = re.sub(r'\s+',' ',text)
    # remove more than one dot by one dot
    text = re.sub(r'\.{2,}', '.', text)
    #remove numbers with no space
    text = re.sub(r'\d+', '', text)
      # Tokenization
    words = word_tokenize(text)
    # Remove punctuation,stopwords and handling the txt with (mapping dictionary) *predefiend above*
    words = [mapping[word] if word in mapping else word for word in words]
    words = [word for word in words if word not in string.punctuation]
    words = [word for word in words if word not in stop_words]

    # optionally lemmatize
    if lemmatize:
        words = [nlp(word)[0].lemma_ for word in words]

    return ' '.join(words)

# %%
# Function performance experiment
print('Original :',data.Review.iloc[0])
print()
print('Porcessed text :',text_preprocessing(data.Review.iloc[0],lemmatize=True))
# Out:
# Original : Wow... Loved this place.
#
# Porcessed text : wow love place

# %%
data['Processed_text'] = data['Review'].apply(lambda x : text_preprocessing(str(x),lemmatize=True))

# %%
 import nltk
 nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
data.head(10)
# Out:
#                                               Review     Liked  \
# 0                           Wow... Loved this place.  Positive
# 1                                 Crust is not good.  Negative
# 2          Not tasty and the texture was just nasty.  Negative
# 3  Stopped by during the late May bank holiday of...  Positive
# 4  The selection on the menu was great and so wer...  Positive
# 5     Now I am getting angry and I want my damn pho.  Negative
# 6              Honeslty it didn't taste THAT fresh.)  Negative
# 7  The potatoes were like rubber and you could te...  Negative
# 8                          The fries were great too.  Positive
# 9                                     A great touch.  Positive
#
#                                       Processed_text
# 0                                     wow love place
# 1                                     crust not good
# 2                            not tasty texture nasty
# 3  stop late may bank holiday rick steve recommen...
# 4                         selection menu great price
# 5                            get angry want damn pho
# 6                           honeslty not taste fresh
# 7  potato like rubber could tell make ahead time ...
# 8                                          fry great
# 9                                        great touch

# %%
data.nunique()
# Out:
# Review            993
# Liked               2
# Processed_text    985
# dtype: int64

# %%
data.nunique()
# Out:
# Review            993
# Liked               2
# Processed_text    985
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(6)

# %%
data.drop_duplicates(inplace=True)
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
def generate_wordcloud(text,bg_color,title ='word cloud'):
    '''
    input : Text ,Back-ground color and Title
    output : Word cloud of most common words with your preferd title and back-ground color
    '''
    wordcloud =WordCloud(background_color=str(bg_color),stopwords=set(stopwords.words('english'))).generate(text)
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(str(title))
    plt.axis("off")
    plt.show()

# %%
generate_wordcloud(" ".join(data[data['Liked']=='Positive']['Processed_text']),bg_color='white',title='Common Positive Words')

# %%
generate_wordcloud(" ".join(data[data['Liked']=='Negative']['Review']),bg_color='black',title='Common Negative Words')

# %%
fig = make_subplots(rows=1, cols=2,specs=[[{'type':'xy'}, {'type':'domain'}]])

fig.add_trace(
    go.Bar(
        x=data['Liked'].value_counts().index,
        y= data['Liked'].value_counts().values,
         marker=dict(color=['#6B816C','#91B092']), showlegend=False,
           text=data['Liked'].value_counts().values, textposition='auto', textfont=dict(size=18)
        ),
    row=1,col=1
    )

fig.add_trace(
    go.Pie(
        labels=data['Liked'].value_counts().index,
        values=data['Liked'].value_counts().values,
         marker=dict(colors=['#6B816C','#91B092']), textfont=dict(size=18),
         pull=[0.01,0.01]
        ),
    row=1,col=2
    )





fig.update_layout(title='<b>Distribution of the target<b>',
                 title_font={'size':25},
                 paper_bgcolor='#E0E1CD',
                 plot_bgcolor='#E0E1CD',
                 showlegend=True)

fig.update_yaxes(showgrid=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="70c73b6c-933f-4010-9680-0f937f24514f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("70c73b6c-933f-4010-9680-0f937f24514f")) {                    Plotly.newPlot(                        "70c73b6c-933f-4010-9680-0f937f24514f",                        [{"marker":{"color":["#6B816C","#91B092"]},"showlegend":false,"text":[498.0,496.0],"textfont":{"size":18},"textposition":"auto","x":["Positive","Negative"],"y":[498,496],"type":"bar","xaxis":"x","yaxis":"y"},{"labels":["Positive","Negative"],"marker":{"colors":["#6B816C","#91B092"]},"pull":[0.01,0.01],"textfont":{"size":18},"values":[498,496],"type":"pie","domain":{"x":[0.55,1.0],"y":[0.0,1.0]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{" ...

# %%
import pandas as pd
from collections import Counter
import plotly.express as px

def plot_commmon_words(data, title):
    '''
    input : Your data and title.
    output : plotting the top 20 common words in the input data with the title you want to put on the figure.
    '''
    # put all words in one list
    corpus = []
    for row in data:
        corpus.extend(row.split())

    # get the most common words (top 20)
    most_common_words = Counter(corpus)
    most_common_words = most_common_words.most_common(20)

    # create the data frame of most common words (top 20)
    tem_df = pd.DataFrame(most_common_words, columns=['word', 'Repetition'])

    # create the figure
    fig = px.bar(tem_df, x="Repetition", y="word", orientation='h', color='word')
    fig.update_layout(
        title=f'<b>{title}</b>',
        title_font={'size': 25},
        paper_bgcolor='#E0E1CD',
        plot_bgcolor='#E0E1CD',
        showlegend=False
    )

    fig.update_yaxes(showgrid=False)
    fig.update_xaxes(showgrid=False)
    fig.show()

# %%
plot_commmon_words(data[data['Liked']=='Positive']['Processed_text'],title='Most common words in positive reviews')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0b533d38-4d61-4e4a-a608-4f7a8e0babce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0b533d38-4d61-4e4a-a608-4f7a8e0babce")) {                    Plotly.newPlot(                        "0b533d38-4d61-4e4a-a608-4f7a8e0babce",                        [{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003eRepetition=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"good","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"good","offsetgroup":"good","orientation":"h","showlegend":true,"textposition":"auto","x":[72],"xaxis":"x","y":["good"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003eRepetition=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"great","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"great","offsetgroup":"great","orientation":"h","showlegend":true,"textposition":"auto","x":[70],"xaxis":"x","y":["great"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003eRepetition=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"place","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"place","offsetgroup":"place","orientation":"h","showlegend":true,"textposition":"auto","x":[59],"xaxis":"x","y":["place"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003eRepetition=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"food","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"food","offsetgroup":"food","orientation":"h","showlegend":true,"textposition":"auto","x":[59],"xaxis":"x","y":["food"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003eRepetition=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"service","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"service","offsetgroup":"service","orientation":"h","showlegend":true,"textposition":"auto","x":[47],"xaxis":"x","y":["service"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003eRepetition=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"not","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"not","offsetgroup":"not","orientation":"h","showlegend":true,"textposition":"auto","x":[37],"xaxis":"x","y":["not"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003eRepetition=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"well","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"well","offsetgroup":"well","orientation":"h","showlegend":true,"textposition":"auto","x":[35],"xaxis":"x","y":["well"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003eRepetition=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"go","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"go","offsetgroup":"go","orientation":"h","showlegend":true,"textposition":"auto","x":[29],"xaxis":"x","y":["go"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003eRepetition=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"love","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"love","offsetgroup":"love","orientation":"h","showlegend":true,"textposition":"auto","x":[27],"xaxis":"x","y":["love"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003eRepetition=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"time","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"time","offsetgroup":"time","orientation":"h","showlegend":true,"textposition":"auto","x":[25] ...

# %%
plot_commmon_words(data[data['Liked']=='Negative']['Processed_text'],title='Most common words in negative reviews')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="25e03f70-f2a7-489d-8215-85c32dc975f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("25e03f70-f2a7-489d-8215-85c32dc975f6")) {                    Plotly.newPlot(                        "25e03f70-f2a7-489d-8215-85c32dc975f6",                        [{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003eRepetition=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"not","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"not","offsetgroup":"not","orientation":"h","showlegend":true,"textposition":"auto","x":[174],"xaxis":"x","y":["not"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003eRepetition=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"food","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"food","offsetgroup":"food","orientation":"h","showlegend":true,"textposition":"auto","x":[65],"xaxis":"x","y":["food"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003eRepetition=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"place","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"place","offsetgroup":"place","orientation":"h","showlegend":true,"textposition":"auto","x":[51],"xaxis":"x","y":["place"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003eRepetition=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"go","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"go","offsetgroup":"go","orientation":"h","showlegend":true,"textposition":"auto","x":[47],"xaxis":"x","y":["go"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003eRepetition=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"service","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"service","offsetgroup":"service","orientation":"h","showlegend":true,"textposition":"auto","x":[38],"xaxis":"x","y":["service"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003eRepetition=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"back","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"back","offsetgroup":"back","orientation":"h","showlegend":true,"textposition":"auto","x":[37],"xaxis":"x","y":["back"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003eRepetition=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"get","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"get","offsetgroup":"get","orientation":"h","showlegend":true,"textposition":"auto","x":[34],"xaxis":"x","y":["get"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003eRepetition=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"like","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"like","offsetgroup":"like","orientation":"h","showlegend":true,"textposition":"auto","x":[31],"xaxis":"x","y":["like"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003eRepetition=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"time","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"time","offsetgroup":"time","orientation":"h","showlegend":true,"textposition":"auto","x":[29],"xaxis":"x","y":["time"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003eRepetition=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"'","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"'","offsetgroup":"'","orientation":"h","showlegend":true,"textposition":"auto","x":[28],"xaxis":"x","y" ...

# %%
plot_commmon_words(data['Processed_text'],title='Most common words in all reviews')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6963e63a-2e59-4b20-abc0-f7cabc25dfc4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6963e63a-2e59-4b20-abc0-f7cabc25dfc4")) {                    Plotly.newPlot(                        "6963e63a-2e59-4b20-abc0-f7cabc25dfc4",                        [{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003eRepetition=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"not","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"not","offsetgroup":"not","orientation":"h","showlegend":true,"textposition":"auto","x":[211],"xaxis":"x","y":["not"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003eRepetition=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"food","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"food","offsetgroup":"food","orientation":"h","showlegend":true,"textposition":"auto","x":[124],"xaxis":"x","y":["food"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003eRepetition=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"place","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"place","offsetgroup":"place","orientation":"h","showlegend":true,"textposition":"auto","x":[110],"xaxis":"x","y":["place"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003eRepetition=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"good","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"good","offsetgroup":"good","orientation":"h","showlegend":true,"textposition":"auto","x":[94],"xaxis":"x","y":["good"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003eRepetition=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"service","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"service","offsetgroup":"service","orientation":"h","showlegend":true,"textposition":"auto","x":[85],"xaxis":"x","y":["service"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003eRepetition=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"go","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"go","offsetgroup":"go","orientation":"h","showlegend":true,"textposition":"auto","x":[76],"xaxis":"x","y":["go"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003eRepetition=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"great","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"great","offsetgroup":"great","orientation":"h","showlegend":true,"textposition":"auto","x":[71],"xaxis":"x","y":["great"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003eRepetition=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"back","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"back","offsetgroup":"back","orientation":"h","showlegend":true,"textposition":"auto","x":[60],"xaxis":"x","y":["back"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003eRepetition=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"well","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"well","offsetgroup":"well","orientation":"h","showlegend":true,"textposition":"auto","x":[60],"xaxis":"x","y":["well"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003eRepetition=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"time","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"time","offsetgroup":"time","orientation":"h","showlegend":true,"textposition":"auto","x":[ ...

# %%
def plot_most_freq_ngrams(text,n,title):
    '''
    input : the text or data,n-grame range and title of the figure.
    output : plotting the most common ngrams as you want
    '''

    #initialize bag of words and fitting the data
    vectorizer = CountVectorizer(ngram_range=(n,n),stop_words=stopwords.words('english'))
    X = vectorizer.fit_transform(text)
    # make a summation of all reapeted ngrams
    feature_counts = X.sum(axis=0)
    # get feature name
    feature_names = vectorizer.get_feature_names_out()
    # prepre df and make sorting to get most common ngrams
    df = pd.DataFrame({'Feature': feature_names, 'Count': feature_counts.tolist()[0]})
    df = df.sort_values(by='Count',ascending=False).head(20).reset_index(drop=True)
    # plotting the figure
    fig = px.bar(df, x="Count", y="Feature" ,orientation='h',
             color='Feature')

    fig.update_layout(title=f'<b>{title}<b>',
                 title_font={'size':25},
                 paper_bgcolor='#E0E1CD',
                 plot_bgcolor='#E0E1CD',
                 showlegend=True)

    fig.update_xaxes(showgrid=False)
    fig.show()

# %%
plot_most_freq_ngrams(data['Processed_text'],n=1,title='most common unigrams to all data')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7bdd408c-51b6-4b5c-9303-69e97499fdcd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7bdd408c-51b6-4b5c-9303-69e97499fdcd")) {                    Plotly.newPlot(                        "7bdd408c-51b6-4b5c-9303-69e97499fdcd",                        [{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"food","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"food","offsetgroup":"food","orientation":"h","showlegend":true,"textposition":"auto","x":[125],"xaxis":"x","y":["food"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"place","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"place","offsetgroup":"place","orientation":"h","showlegend":true,"textposition":"auto","x":[110],"xaxis":"x","y":["place"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"good","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"good","offsetgroup":"good","orientation":"h","showlegend":true,"textposition":"auto","x":[94],"xaxis":"x","y":["good"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"service","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"service","offsetgroup":"service","orientation":"h","showlegend":true,"textposition":"auto","x":[85],"xaxis":"x","y":["service"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"go","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"go","offsetgroup":"go","orientation":"h","showlegend":true,"textposition":"auto","x":[76],"xaxis":"x","y":["go"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"great","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"great","offsetgroup":"great","orientation":"h","showlegend":true,"textposition":"auto","x":[71],"xaxis":"x","y":["great"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"well","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"well","offsetgroup":"well","orientation":"h","showlegend":true,"textposition":"auto","x":[61],"xaxis":"x","y":["well"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"back","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"back","offsetgroup":"back","orientation":"h","showlegend":true,"textposition":"auto","x":[60],"xaxis":"x","y":["back"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"time","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"time","offsetgroup":"time","orientation":"h","showlegend":true,"textposition":"auto","x":[54],"xaxis":"x","y":["time"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"like","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"like","offsetgroup":"like","orientation":"h","showlegend":true,"textposition":"auto","x":[51],"xaxis":"x"," ...

# %%
plot_most_freq_ngrams(data['Processed_text'],n=2,title='most common bigrams to all data')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="892beb7b-5246-4930-b472-786aa2c85036" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("892beb7b-5246-4930-b472-786aa2c85036")) {                    Plotly.newPlot(                        "892beb7b-5246-4930-b472-786aa2c85036",                        [{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"go back","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"go back","offsetgroup":"go back","orientation":"h","showlegend":true,"textposition":"auto","x":[27],"xaxis":"x","y":["go back"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"come back","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"come back","offsetgroup":"come back","orientation":"h","showlegend":true,"textposition":"auto","x":[11],"xaxis":"x","y":["come back"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"good food","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"good food","offsetgroup":"good food","orientation":"h","showlegend":true,"textposition":"auto","x":[8],"xaxis":"x","y":["good food"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"feel like","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"feel like","offsetgroup":"feel like","orientation":"h","showlegend":true,"textposition":"auto","x":[8],"xaxis":"x","y":["feel like"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"great food","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"great food","offsetgroup":"great food","orientation":"h","showlegend":true,"textposition":"auto","x":[8],"xaxis":"x","y":["great food"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"food good","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"food good","offsetgroup":"food good","orientation":"h","showlegend":true,"textposition":"auto","x":[8],"xaxis":"x","y":["food good"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"great place","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"great place","offsetgroup":"great place","orientation":"h","showlegend":true,"textposition":"auto","x":[6],"xaxis":"x","y":["great place"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"first time","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"first time","offsetgroup":"first time","orientation":"h","showlegend":true,"textposition":"auto","x":[6],"xaxis":"x","y":["first time"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"great service","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"great service","offsetgroup":"great service","orientation":"h","showlegend":true,"textposition":"auto","x":[6],"xaxis":"x","y":["great service"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","lege ...

# %%
plot_most_freq_ngrams(data['Processed_text'],n=3,title='most common trigrams to all data')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="563d7f1c-96f5-4367-9a2a-2e516941e550" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("563d7f1c-96f5-4367-9a2a-2e516941e550")) {                    Plotly.newPlot(                        "563d7f1c-96f5-4367-9a2a-2e516941e550",                        [{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"back anytime soon","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"back anytime soon","offsetgroup":"back anytime soon","orientation":"h","showlegend":true,"textposition":"auto","x":[3],"xaxis":"x","y":["back anytime soon"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"go back anytime","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"go back anytime","offsetgroup":"go back anytime","orientation":"h","showlegend":true,"textposition":"auto","x":[3],"xaxis":"x","y":["go back anytime"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ever go back","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"ever go back","offsetgroup":"ever go back","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["ever go back"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"great place eat","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"great place eat","offsetgroup":"great place eat","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["great place eat"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"think go back","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"think go back","offsetgroup":"think go back","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["think go back"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"food great service","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"food great service","offsetgroup":"food great service","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["food great service"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"would go back","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"would go back","offsetgroup":"would go back","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["would go back"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"much rather go","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"much rather go","offsetgroup":"much rather go","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["much rather go"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"good thing place","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"good thing place","offsetgroup":"good thing place","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis ...

# %%
plot_most_freq_ngrams(data[data['Liked']=='Positive']['Processed_text'],n=2,title='most common bigrams to positve reviews')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="583efef2-8c3b-4a60-8da7-b2b8489c597d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("583efef2-8c3b-4a60-8da7-b2b8489c597d")) {                    Plotly.newPlot(                        "583efef2-8c3b-4a60-8da7-b2b8489c597d",                        [{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"great food","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"great food","offsetgroup":"great food","orientation":"h","showlegend":true,"textposition":"auto","x":[8],"xaxis":"x","y":["great food"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"go back","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"go back","offsetgroup":"go back","orientation":"h","showlegend":true,"textposition":"auto","x":[7],"xaxis":"x","y":["go back"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"food good","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"food good","offsetgroup":"food good","orientation":"h","showlegend":true,"textposition":"auto","x":[7],"xaxis":"x","y":["food good"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"come back","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"come back","offsetgroup":"come back","orientation":"h","showlegend":true,"textposition":"auto","x":[6],"xaxis":"x","y":["come back"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"great place","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"great place","offsetgroup":"great place","orientation":"h","showlegend":true,"textposition":"auto","x":[6],"xaxis":"x","y":["great place"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"great service","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"great service","offsetgroup":"great service","orientation":"h","showlegend":true,"textposition":"auto","x":[6],"xaxis":"x","y":["great service"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"first time","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"first time","offsetgroup":"first time","orientation":"h","showlegend":true,"textposition":"auto","x":[5],"xaxis":"x","y":["first time"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"food delicious","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"food delicious","offsetgroup":"food delicious","orientation":"h","showlegend":true,"textposition":"auto","x":[5],"xaxis":"x","y":["food delicious"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"food great","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"food great","offsetgroup":"food great","orientation":"h","showlegend":true,"textposition":"auto","x":[5],"xaxis":"x","y":["food great"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u ...

# %%
plot_most_freq_ngrams(data[data['Liked']=='Positive']['Processed_text'],n=3,title='most common trigrams to positve reviews')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f3bcc9d7-5ebc-4f1c-819f-3ee5c03b80e0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f3bcc9d7-5ebc-4f1c-819f-3ee5c03b80e0")) {                    Plotly.newPlot(                        "f3bcc9d7-5ebc-4f1c-819f-3ee5c03b80e0",                        [{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"food great service","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"food great service","offsetgroup":"food great service","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["food great service"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"good thing place","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"good thing place","offsetgroup":"good thing place","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["good thing place"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"first vegas buffet","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"first vegas buffet","offsetgroup":"first vegas buffet","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["first vegas buffet"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"great place eat","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"great place eat","offsetgroup":"great place eat","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["great place eat"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"food good service","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"food good service","offsetgroup":"food good service","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["food good service"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"come back every","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"come back every","offsetgroup":"come back every","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["come back every"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"great food great","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"great food great","offsetgroup":"great food great","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["great food great"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"pretty cool would","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"pretty cool would","offsetgroup":"pretty cool would","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["pretty cool would"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"pretty awesome place","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"pretty awesome place","offsetgroup":"pretty awesome place", ...

# %%
plot_most_freq_ngrams(data[data['Liked']=='Negative']['Processed_text'],n=2,title='most common bigrams to negative reviews')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e7c92467-0e0d-4fbc-b24b-1d8f655f0424" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e7c92467-0e0d-4fbc-b24b-1d8f655f0424")) {                    Plotly.newPlot(                        "e7c92467-0e0d-4fbc-b24b-1d8f655f0424",                        [{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"go back","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"go back","offsetgroup":"go back","orientation":"h","showlegend":true,"textposition":"auto","x":[20],"xaxis":"x","y":["go back"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"anytime soon","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"anytime soon","offsetgroup":"anytime soon","orientation":"h","showlegend":true,"textposition":"auto","x":[5],"xaxis":"x","y":["anytime soon"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"get food","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"get food","offsetgroup":"get food","orientation":"h","showlegend":true,"textposition":"auto","x":[5],"xaxis":"x","y":["get food"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"come back","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"come back","offsetgroup":"come back","orientation":"h","showlegend":true,"textposition":"auto","x":[5],"xaxis":"x","y":["come back"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"another minute","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"another minute","offsetgroup":"another minute","orientation":"h","showlegend":true,"textposition":"auto","x":[4],"xaxis":"x","y":["another minute"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"wait wait","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"wait wait","offsetgroup":"wait wait","orientation":"h","showlegend":true,"textposition":"auto","x":[4],"xaxis":"x","y":["wait wait"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"zero star","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"zero star","offsetgroup":"zero star","orientation":"h","showlegend":true,"textposition":"auto","x":[4],"xaxis":"x","y":["zero star"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"never ever","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"never ever","offsetgroup":"never ever","orientation":"h","showlegend":true,"textposition":"auto","x":[4],"xaxis":"x","y":["never ever"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"bad food","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"bad food","offsetgroup":"bad food","orientation":"h","showlegend":true,"textposition":"auto","x":[4],"xaxis":"x","y":["bad food"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgro ...

# %%
plot_most_freq_ngrams(data[data['Liked']=='Negative']['Processed_text'],n=3,title='most common trigrams to negative reviews')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="91f54824-7787-4444-8910-d7f1ad1fb4e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("91f54824-7787-4444-8910-d7f1ad1fb4e9")) {                    Plotly.newPlot(                        "91f54824-7787-4444-8910-d7f1ad1fb4e9",                        [{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"back anytime soon","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"back anytime soon","offsetgroup":"back anytime soon","orientation":"h","showlegend":true,"textposition":"auto","x":[3],"xaxis":"x","y":["back anytime soon"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"go back anytime","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"go back anytime","offsetgroup":"go back anytime","orientation":"h","showlegend":true,"textposition":"auto","x":[3],"xaxis":"x","y":["go back anytime"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"much rather go","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"much rather go","offsetgroup":"much rather go","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["much rather go"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"run around like","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"run around like","offsetgroup":"run around like","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["run around like"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"give zero star","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"give zero star","offsetgroup":"give zero star","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["give zero star"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"service extremely slow","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"service extremely slow","offsetgroup":"service extremely slow","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["service extremely slow"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"never ever go","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"never ever go","offsetgroup":"never ever go","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["never ever go"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"zero star would","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"zero star would","offsetgroup":"zero star would","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["zero star would"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Feature=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"never go back","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"never go back","offsetgroup":"never go back","orientation":"h","showlegend":true,"textposition ...

# %%
data['words_len'] = data['Review'].apply(lambda x : len(x.split()))
data.head()
# Out:
#                                               Review     Liked  \
# 0                           Wow... Loved this place.  Positive
# 1                                 Crust is not good.  Negative
# 2          Not tasty and the texture was just nasty.  Negative
# 3  Stopped by during the late May bank holiday of...  Positive
# 4  The selection on the menu was great and so wer...  Positive
#
#                                       Processed_text  words_len
# 0                                     wow love place          4
# 1                                     crust not good          4
# 2                            not tasty texture nasty          8
# 3  stop late may bank holiday rick steve recommen...         15
# 4                         selection menu great price         12

# %%
fig = go.Figure()

fig.add_trace(go.Violin(x=data[data['Liked']=='Positive']['words_len'],line_color='#91B092',y0=0,name='Positive'))
fig.add_trace(go.Violin(x=data[data['Liked']=='Negative']['words_len'],line_color='#6B816C',y0=0,name='Negative'))
fig.update_traces(orientation='h',side='positive',meanline_visible=True)

fig.update_layout(title = "<b> distribution of word counts in positive & negative reviews",
                 titlefont={'size':20},
                 xaxis_zeroline=False,
                 paper_bgcolor='#E0E1CD',
                 plot_bgcolor='#E0E1CD')
fig.update_xaxes(showgrid=False,title='Word length')
fig.update_yaxes(showgrid=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="abac1b7a-477d-4b51-a0bd-de4a1ca4c787" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("abac1b7a-477d-4b51-a0bd-de4a1ca4c787")) {                    Plotly.newPlot(                        "abac1b7a-477d-4b51-a0bd-de4a1ca4c787",                        [{"line":{"color":"#91B092"},"name":"Positive","x":[4,15,12,5,3,4,9,2,3,4,9,3,10,13,17,12,7,13,5,8,5,13,13,8,10,19,21,17,6,4,9,19,7,7,6,8,12,7,13,7,17,1,10,16,4,15,10,5,5,20,3,4,3,10,28,17,11,19,12,10,16,9,6,2,13,4,2,3,8,29,21,5,17,3,24,13,19,7,11,13,19,11,19,9,7,10,21,23,4,4,7,8,1,16,4,24,5,16,20,12,17,18,11,2,9,21,8,7,18,11,3,5,18,8,3,5,4,14,6,2,4,5,6,5,12,13,14,4,21,21,8,6,4,13,10,5,8,12,12,3,7,6,5,8,8,5,14,13,8,10,4,14,9,9,12,13,11,4,4,15,9,8,12,9,9,2,15,9,2,5,13,19,20,6,12,12,6,8,4,23,15,10,4,4,5,13,12,6,5,7,10,8,13,5,3,15,10,8,9,16,5,10,13,8,4,10,20,6,10,4,10,10,7,11,24,16,12,21,22,17,11,8,19,25,6,10,3,14,6,9,5,12,26,15,2,13,10,4,5,3,6,12,5,7,5,8,15,14,21,11,4,20,7,6,4,16,12,9,10,4,13,3,3,6,10,19,3,22,7,12,21,4,7,13,4,10,11,10,12,5,20,8,4,7,17,10,9,3,8,10,15,16,10,7,4,23,12,5,5,7,14,25,8,8,14,10,9,5,18,30,14,2,7,7,4,3,19,5,3,11,11,8,8,18,5,11,10,20,8,11,13,10,10,17,10,9,6,7,4,3,17,4,8,10,12,3,3,21,24,7,7,6,25,5,6,8,2,11,15,6,6,13,7,14,18,9,10,2,2,19,5,19,17,5,5,4,5,6,9,13,5,5,3,21,11,15,6,4,4,14,19,11,13,12,5,14,10,3,11,21,6,6,4,19,10,18,4,5,28,8,9,8,8,21,14,10,7,13,18,9,19,14,11,13,11,15,17,7,6,9,6,16,4,12,15,9,6,8,6,9,16,6,17,21,6,21,7,32,12,4,10,5,7,5,10,11,21,8,8,21,8,17,3,9,12,8,14,16,9,10,9,9,25,11,11,7,6,17,14,11,13,17,14,5,10,4,5,11,12,13,14,5,7,4,14,8,8,13],"y0":0,"type":"violin","meanline":{"visible":true},"orientation":"h","side":"positive"},{"line":{"color":"#6B816C"},"name":"Negative","x":[4,8,11,6,22,4,21,12,9,7,10,5,3,1,27,6,6,23,18,2,15,28,13,9,18,15,12,11,17,20,4,16,25,10,8,23,22,17,7,21,12,9,15,7,4,4,12,17,4,4,11,19,23,12,10,26,3,9,4,23,3,11,16,15,15,24,6,15,8,8,16,11,4,11,6,19,20,9,15,23,23,8,4,15,10,19,7,8,5,19,4,9,30,20,3,4,8,25,6,19,17,11,6,17,18,12,24,22,8,16,10,15,12,22,7,27,10,7,21,8,10,15,4,18,3,4,12,9,18,19,20,8,20,28,9,9,23,4,10,5,19,10,3,10,25,6,13,22,20,16,3,18,15,7,6,12,11,3,9,17,12,17,12,10,14,6,9,9,4,25,4,4,13,16,13,4,16,6,12,12,3,4,7,11,12,7,18,11,16,5,4,7,4,14,15,7,2,4,3,9,26,4,11,12,7,5,13,27,11,5,16,9,15,18,8,12,14,16,4,6,6,7,6,2,2,7,10,4,9,18,6,2,11,3,21,10,15,10,6,13,12,16,3,10,14,5,17,18,3,4,7,13,5,11,12,5,2,10,15,11,6,7,14,10,5,23,5,7,21,13,17,12,8,16,4,10,2,32,12,11,24,9,7,11,15,4,11,11,3,3,5,7,9,9,7,9,3,10,8,6,10,3,8,7,24,3,10,19,13,7,17,5,18,3,9,9,21,9,21,11,8,9,5,23,14,4,14,18,17,8,11,11,6,3,9,15,8,10,19,6,5,13,11,6,6,29,22,2,3,8,24,25,20,5,14,3,11,7,8,6,2,5,5,16,7,14,10,3,20,17,23,9,10,9,5,17,27,7,17,12,7,7,26,22,16,11,4,5,8,17,12,7,18,26,10,5,8,23,10,3,8,4,10,6,12,9,4,24,3,16,17,9,17,13,8,16,22,10,4,7,13,15,12,15,21,2,16,19,8,5,12,4,14,4,13,17,4,8,7,8,11,15,13,4,7,18,10,23,21,3,10,6,7,6,17,25,18,24,14,13,11,8,5,6,21,17,29,5,11,4,9,6,15,6,7,17,23,15,4,21,12,28,18,7,10,12,18,8,16,7,8,12,3,10,16,28],"y0":0,"type":"violin","meanline":{"visible":true},"orientation":"h","side":"positive"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"], ...

# %%
data['Review_len'] = data['Review'].apply(lambda x :len(x))
data.head()
# Out:
#                                               Review     Liked  \
# 0                           Wow... Loved this place.  Positive
# 1                                 Crust is not good.  Negative
# 2          Not tasty and the texture was just nasty.  Negative
# 3  Stopped by during the late May bank holiday of...  Positive
# 4  The selection on the menu was great and so wer...  Positive
#
#                                       Processed_text  words_len  Review_len
# 0                                     wow love place          4          24
# 1                                     crust not good          4          18
# 2                            not tasty texture nasty          8          41
# 3  stop late may bank holiday rick steve recommen...         15          87
# 4                         selection menu great price         12          59

# %%
import plotly.figure_factory as ff

fig = ff.create_distplot(
    [data[data['Liked'] == 'Positive']['Review_len'], data[data['Liked'] == 'Negative']['Review_len']],
    ['Positive', 'Negative'],
    show_hist=True,
    show_rug=False,
)

# Update the colors of both histograms and curves
fig['data'][0].marker.color = '#91B092'  # Positive color for the histogram
fig['data'][1].marker.color = '#6B816C'  # Negative color for the histogram

fig['data'][2].line.color = '#91B092'  # Positive color for the curve
fig['data'][3].line.color = '#6B816C'  # Negative color for the curve

fig.update_layout(
     title='<b>Distribution of review Length in positive & negative reviews</b>',
    titlefont={'size': 20},
    paper_bgcolor='#E0E1CD',
    plot_bgcolor='#E0E1CD',
    showlegend=True
)

fig.update_xaxes(showgrid=False ,title='Review length')
fig.update_yaxes(showgrid=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e83bd3ab-1aaf-4ba8-9fec-de6ff1941958" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e83bd3ab-1aaf-4ba8-9fec-de6ff1941958")) {                    Plotly.newPlot(                        "e83bd3ab-1aaf-4ba8-9fec-de6ff1941958",                        [{"autobinx":false,"histnorm":"probability density","legendgroup":"Positive","marker":{"color":"#91B092"},"name":"Positive","opacity":0.7,"x":[24,87,59,25,14,24,60,19,18,21,52,18,67,73,83,58,33,78,31,37,28,77,64,43,52,102,98,90,27,21,72,103,49,45,35,35,72,35,71,30,91,6,56,80,18,64,44,23,35,117,24,19,21,51,146,90,54,113,54,55,91,53,27,13,77,23,12,13,47,140,111,38,96,22,139,81,105,39,48,72,87,63,88,47,44,52,109,126,19,25,45,43,11,81,21,121,33,72,127,72,81,99,69,18,46,120,49,37,94,45,20,22,94,38,18,33,21,80,34,16,25,35,32,32,61,60,84,19,109,121,65,35,36,63,49,33,49,62,54,23,32,32,40,51,46,24,82,51,45,44,20,82,43,50,59,77,60,23,22,83,51,50,58,49,52,19,77,36,15,23,68,101,100,31,63,61,46,49,26,116,73,61,18,23,28,63,68,34,31,40,87,37,71,36,19,83,59,35,47,87,24,54,62,43,20,66,106,27,54,24,64,46,33,60,124,85,73,135,147,83,60,52,93,119,33,47,22,61,37,48,29,61,146,95,14,76,61,24,30,24,37,58,29,37,20,59,74,75,101,67,19,116,32,33,19,98,47,47,61,25,66,18,20,32,58,92,11,110,40,74,116,20,31,57,31,52,58,60,67,29,121,45,28,41,88,41,45,23,44,48,82,82,51,32,27,107,55,28,30,38,68,137,56,55,66,58,54,37,82,148,73,14,39,39,21,12,94,34,19,62,55,44,47,93,34,61,42,126,34,75,60,56,47,98,48,45,38,40,17,15,90,23,43,52,72,21,20,114,101,43,49,36,131,21,36,57,11,57,76,39,42,81,33,84,114,50,57,11,19,94,29,98,83,32,33,25,32,24,45,54,33,34,16,110,62,86,26,26,24,83,114,60,71,61,27,66,59,13,62,118,35,29,29,108,54,93,26,31,138,40,42,47,43,107,83,57,42,68,90,57,104,76,61,70,66,71,80,29,33,50,27,75,22,78,69,45,44,41,36,47,84,27,89,115,44,87,45,146,63,33,55,31,36,38,50,67,106,39,47,115,42,87,20,47,67,33,76,74,47,53,49,44,115,62,60,35,35,98,80,48,71,104,77,22,60,32,32,68,62,63,68,30,37,28,97,55,37,70],"xaxis":"x","xbins":{"end":148.0,"size":1.0,"start":6.0},"yaxis":"y","type":"histogram"},{"autobinx":false,"histnorm":"probability density","legendgroup":"Negative","marker":{"color":"#6B816C"},"name":"Negative","opacity":0.7,"x":[18,41,46,37,111,18,99,62,50,38,51,20,19,6,141,33,29,115,88,14,81,147,75,41,112,93,59,67,84,98,20,87,128,54,37,119,133,87,37,110,73,63,80,29,21,16,59,92,20,27,45,107,126,62,52,131,18,51,23,120,15,63,85,72,84,119,23,77,41,44,99,63,18,53,31,114,100,44,75,132,114,37,21,82,52,99,40,51,26,100,26,42,139,106,14,19,40,127,30,118,89,54,36,102,111,60,142,98,43,80,61,78,58,116,55,146,59,36,97,38,61,81,17,80,20,20,64,51,86,101,94,38,106,132,43,52,118,23,60,25,95,61,17,42,132,33,66,115,90,88,21,105,82,44,44,75,56,16,47,93,60,82,64,55,61,32,45,41,32,126,16,22,68,82,61,19,70,36,69,61,21,20,34,51,58,37,124,67,80,24,18,33,19,79,73,47,16,17,20,47,138,18,47,70,35,26,68,146,62,27,90,49,80,100,39,49,65,93,24,39,33,42,35,17,24,28,44,25,44,92,28,20,52,19,115,48,71,46,32,61,74,81,25,60,70,28,88,93,21,22,47,82,29,52,58,26,11,51,83,58,28,47,63,45,23,129,23,33,120,66,90,59,39,78,18,47,21,147,73,64,119,50,39,49,75,20,64,53,20,15,25,36,54,53,31,54,13,47,46,35,58,18,39,34,122,16,50,102,73,43,107,30,88,13,46,52,124,43,104,75,54,49,22,107,67,17,96,85,73,42,49,57,31,17,54,76,41,56,97,34,31,71,56,27,32,134,100,14,16,50,132,119,109,32,86,15,59,39,42,29,14,25,31,72,33,83,49,18,92,77,127,54,49,48,29,92,139,35,99,69,37,39,147,116,77,57,23,26,46,92,50,44,100,133,49,31,37,122,49,16,49,27,55,32,58,61,22,145,15,93,94,47,86,74,40,81,121,52,25,33,70,85,49,68,112,25,72,101,48,23,63,25,72,25,66,100,21,35,43,43,69,90,67,25,42,96,42,118,111,20,50,29,46,39,89,120,107,114,78,82,59,41,20,22,122,81,136,31,70,21,62,45,75,36,36,80,113,88,23,105,44 ...

# %%
data['Liked'] = data['Liked'].map({'Positive':1,'Negative':0})
data.head()
# Out:
#                                               Review  Liked  \
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1
#
#                                       Processed_text  words_len  Review_len
# 0                                     wow love place          4          24
# 1                                     crust not good          4          18
# 2                            not tasty texture nasty          8          41
# 3  stop late may bank holiday rick steve recommen...         15          87
# 4                         selection menu great price         12          59

# %%
X = data['Processed_text']
y = data ['Liked']

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2,shuffle=True,random_state=42)

# %%
print('x train shape : ',x_train.shape)
print('x test shape : ',x_test.shape)
print('y train shape : ',y_train.shape)
print('y test shape : ',y_test.shape)
# Out:
# x train shape :  (795,)
# x test shape :  (199,)
# y train shape :  (795,)
# y test shape :  (199,)
